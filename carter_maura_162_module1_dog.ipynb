# %% [markdown]
# <a href="https://colab.research.google.com/github/mauracarter-statistics/csc162/blob/main/carter_maura_162_module1_dog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #INSTRUCTIONS - Module 1 Week 2 - DUE NOV. 3
#
# #Assignment Tasks:
#
# #Environment Setup: • Open a new Google Colab notebook. • Install and import the required libraries by running the following code.
#
# #Image Input: • Download the dog image from the provided link or load it directly using its URL in your notebook. • Read the image using cv2.imread() and display it using the proper conversion from BGR to RGB.
#
# #1) Basic Manipulations: Implement the following tasks on the dog image:
#
# #2) Resizing: Resize the image to a fixed dimension (e.g., 400x300 pixels) using cv2.resize().
#
# #3) Cropping: Crop a region of the image (e.g., using slicing: img[50:250, 100:400]).
#
# #4) Rotating: Rotate the image by 45 degrees by generating a rotation matrix with cv2.getRotationMatrix2D() and applying it with cv2.warpAffine().
#
# #5) Color Space Conversion: Convert the image to grayscale using cv2.cvtColor() with the cv2.COLOR_BGR2GRAY parameter.
#
# #6) Drawing: Draw a red rectangle (or any other shape/text) on the image using cv2.rectangle() (and optionally, other drawing functions like cv2.circle() or cv2.putText()).
#
# #7) Additional Exploration: (Optional) • Convert the image to an alternative color space (e.g., HSV) and experiment with additional drawing and filtering operations.

# %% [markdown]
# **Environment Setup:** • Open a new Google Colab notebook. • Install and import the required libraries by running the following code:

# %%
#python
# !pip install --upgrade opencv-python-headless
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
